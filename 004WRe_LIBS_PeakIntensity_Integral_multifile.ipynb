# %%
# %matplotlib inline
#行番号 esc+l(エル)
import os
import numpy as np
import scipy as sp
import scipy.optimize as opt
import math as math
import matplotlib.pyplot as plt
import itertools as IT
from scipy import integrate
from scipy.integrate import simps
from scipy.signal import argrelmax
from scipy import stats

###IMPORT ORIGINAL FUNCTIONS##################################################
from func000_Plotset import plot_ini
from func000_Plotset import plotset
plot_ini()
from func001_PeakFit import norm
from func001_PeakFit import peakfind
from func001_PeakFit import peakfit
#iはファイル番号に対応　i=1>A001.cdat
fil_i=list(range(1,22,1)) # a1以上a2未満までを2ステップで作成　b = list(range(a1, a2, 2))

###INITIAL PATH AND IN/OUT FILE NAMES#########################################
pathINITI="C:/Users/Ibano/Anaconda3/jupyter/LIBS"
pathDATA="20180918/ME5000"
pathOUT="PeakAndIntensity.dat"
pathOUT2="BoltzmannPlot.dat"
pathOUT3="summary.dat"
path2nd="W-Re_fitting.dat"
flib1="../../lib/W-I.sdat"
lib1=flib1

label1st='W data'
label2nd='Re data'
Mat1st='W'
Mat2nd='Re'
Mat="W-Re"
label3='Fitting W line'
label4='Re Line (slope from W data)'

pathPARTW="../../../../lib/partition_func/W-I_pf.dat"
pathPARTW2="../../../../lib/partition_func/Re-I-WRe_pf.dat"
i=1
fil_a=[""]*99
while i<99:
    if i<10:
        fil_a[i-1]='cdat/A_00{0:}.cdat'.format(i)
    if i>9:
        fil_a[i-1]='cdat/A_0{0:}.cdat'.format(i)
    i += 1
file_list=fil_a

#f1="cdat/MechelleSpect_001.cdat"
#f2="cdat/MechelleSpect_002.cdat"
#f3="cdat/MechelleSpect_003.cdat"
#f4="cdat/MechelleSpect_004.cdat"
#file_list=[f1,f2,f3,f4]

x_fit=np.arange(0,6,.1)
    
###INITIAL VALUABLES FOR PEAK FITTING#########################################
sd1= 0.03
a1= 4.0e19
##############################################################################

os.chdir(pathINITI)
print("initial directory")
init_dir=os.getcwd()
print(os.getcwd())
os.chdir(pathDATA)

######READING W LIBRARY DATA####################################
################################################################
#for lib1 in lib_list:
with open(lib1, 'rb') as lib:
#    sdat = IT.chain(IT.islice(lib, 0), IT.islice(lib, 4, None))
    FL = np.genfromtxt(lib,delimiter=None,skip_header=4) #np.genfromtxt(sdat)
LibWavelength,LibWave1,LibWave2 = FL[:,0],FL[:,1],FL[:,2]
LibAki,LibFik,LibEi = FL[:,3],FL[:,4],FL[:,5]
LibEk,LibGi,LibGk = FL[:,6],FL[:,7],FL[:,8]
print("LibWavelength",LibWavelength)
######READING EXPERIMENTAL SPECTRUM DATA########################
if not os.path.exists('python'):
    os.makedirs('python')

loop_dir=os.getcwd()

for i in fil_i:
    file1=file_list[i-1]    
    print("loop number={}, dir?".format(i))
    print(os.getcwd())
    print(file1)
    with open(file1, 'rb') as file:
        SPEC = np.loadtxt(file, skiprows=12,delimiter=None,  unpack=True)
    datapath='MechelleSpect_00{0:}'.format(i)

    if not os.path.exists('python/'+datapath):
        os.makedirs('python/'+datapath)

    os.chdir('python/'+datapath)
    XX=SPEC[0]
    YY=SPEC[3]
#################################################################

    ###plotting entire spectrum###########    
    plt.plot(XX,YY);
    plt.xlabel('Wavelengh[nm]');
    plt.ylabel('Intensity [cps]');
    plt.savefig("004-1_Spectral.png",format = 'png', dpi=300)
    plt.close()
    ######################################
    
    
###Peak fitting for individual peaks at experimental data################### 
    with open(pathOUT, mode='w') as f:
        f.write("x_peak,x_min,x_max,Aki,Fik, Ei,Ek,Gi,Gk,Integral,Ln(IperGA) \n")
        
    if not os.path.exists('Wfitting'):
        os.makedirs('Wfitting')
    os.chdir('Wfitting')
    k=0
    for WL1 in LibWavelength:
        nx=100
        ###Using data from library for initial values at fitting############
        x_peak=LibWavelength[k]
        x_min=LibWave1[k]
        x_max=LibWave2[k]
        Aki,Fik, Ei,Ek,Gi,Gk = LibAki[k],LibFik[k],LibEi[k],LibEk[k],LibGi[k],LibGk[k]
        ###Peak fitting and Integration#####################################
        ###1st step: correction for peak shift##############################
        del_x=peakfind(x_peak,x_min,x_max,nx,XX,YY,k)
        x_peak += del_x
        x_min -= abs(del_x)
        x_max += abs(del_x)
        ###2nd step: first fitting for peak dispertion determination######
        Integral,m1_cal,sd_cal=peakfit(x_peak,x_min,x_max,nx,XX,YY,sd1,a1,k,0) 
        x_peak=m1_cal
        x_min=x_peak-sd_cal*10
        x_max=x_peak+sd_cal*10
        ###3rd step: final fitting for the peak#############################
        Integral,m1_cal,sd_cal=peakfit(x_peak,x_min,x_max,nx,XX,YY,sd1,a1,k,1)
        ####################################################################            
        ###output of peak fitting data######################################            
        dataset=[Aki,Fik, Ei,Ek,Gi,Gk]
        IperGA=np.log(Integral/Gk/Aki)
        output=np.c_[x_peak,x_min,x_max,Aki,Fik, Ei,Ek,Gi,Gk,Integral,IperGA]
        with open("../"+pathOUT, mode='ab') as f:
            np.savetxt(f,output, fmt='%.4e',delimiter=', ')
        ####################################################################    
        k+=1
    
    os.chdir("../")
###Boltzmann plot and fitting for Te and intercept#########################  
    with open(pathOUT, 'rb') as path:
        RESULT = np.genfromtxt(path,delimiter=',',skip_header=1)
    print("RESULT")
    #print(RESULT)
    RESULT=RESULT[~np.isnan(RESULT).any(axis=1)]
    #print(RESULT)
    
#    RESULT = np.loadtxt(pathOUT, delimiter=',', skiprows=1)
    
    Ek_result=RESULT[:,6]
    IperGA_result=RESULT[:,10]
    
    m, qs = np.polyfit(Ek_result, IperGA_result, 1)# 1st order line fitting    
    p = [m, qs] # Initial guesses for leastsq

    def line(p, x, y):
      slope, intercept = p
      y_temp = slope*x + intercept
      err = y - y_temp
      return err
    
    #IperGA_result =[28.060805,29.714654,27.074535,30.195656,29.576861,30.925483, 30.198635, 30.773779]
    
    out = opt.leastsq(line, p, args = (Ek_result,IperGA_result))
    m, qs= out[0]
    
    x=Ek_result
    y=IperGA_result
    N=len(x)
    err=(sum((y-(m*x+qs))**2)/N)**0.5
    errm=err*(N/(N*sum(x**2)-sum(x)**2))**0.5
    errqs=err*(sum(x**2)/(N*sum(x**2)-sum(x)**2))**0.5
    y_fit = m * x_fit + qs
    kB = 8.617e-5
    Te = -1.0/m
    errTe = 1.0/m/m*errm #誤差の伝搬
    ###READ PARTITION FUNCTION##############################################
    print("current dir",os.getcwd())
    dataUs = np.loadtxt(pathPARTW, delimiter='  ', skiprows=2)
    xTe=dataUs[:,0] # Te 
    yUs=dataUs[:,1] # Us(Partition function)
    
    j=0
    while xTe[j] < Te:
        xTe1=xTe[j]
        xTe2=xTe[j+1]
        j += 1
    Us = (yUs[j]-yUs[j-1])/(xTe[j]-xTe[j-1])*(Te-xTe[j-1])+yUs[j-1]
    ########################################################################
    ######################################################################## 
    ###READ 2nd ELEMENT SIGNAL############################################## 
    RESULT2 = np.loadtxt(path2nd, delimiter=',', skiprows=1)
    
    Ek2_result=RESULT2[6]
    IperGA2_result=RESULT2[10]
    ###Making line for the 2nd element signal############################### 
    #y=m2 * x+ qs2,m2=m ==> qs2 =y-m*x
    m2=m
    qs2=IperGA2_result-m2*Ek2_result
    y2_fit=m2 * x_fit + qs2
    ###READ PARTITION FUNCTION##############################################
    
    dataUs = np.loadtxt(pathPARTW2, delimiter='  ', skiprows=2)
    xTe2=dataUs[:,0] # Te 
    yUs2=dataUs[:,1] # Us(Partition function)
    
    j=0
    while xTe2[j] < Te:
        xTeI=xTe[j]
        xTeII=xTe[j+1]
        j += 1
        
    Us2 = (yUs2[j]-yUs2[j-1])/(xTe2[j]-xTe2[j-1])*(Te-xTe2[j-1])+yUs2[j-1]
    ########################################################################
    ###Determination of experimental factor F###############################
    F = Us*np.exp(qs)+Us2*np.exp(qs2)
    ########################################################################
    ###Determination of concentration#######################################
    Cs=Us/F*np.exp(qs)
    Cs2 = Us2/F*np.exp(qs2)
    ######################################################################## 
    
    ####Plotting Boltzmann##################################################
    plt.plot(Ek_result, IperGA_result,'o', label=label1st)
    plt.plot(Ek2_result, IperGA2_result,'x', label=label2nd)
    plt.plot(x_fit, y_fit,'-', label=label3)
    plt.plot(x_fit, y2_fit,'-', label=label4)
    title=Mat1st+' FIT:{0:+3.3f}*x{1:+3.3f}  Te:{2:3.3f} (eV) \n'.format(m, qs, Te)
    title=title+"{0:3.3f}, {1:3.3f}, {2:3.3f}\n".format(errm,errqs,errTe)
    title=title+Mat2nd+' FIT:{0:+3.3f}*x{1:+3.3f} '.format(m2, qs2)
    plt.title(title,fontsize=12)
    plt.xlabel('$\mathsf{E_k (eV)}$')
    plt.ylabel('$\mathsf{ln(I_{ki}/g_k A_{ki})}$')
    plotset()
    plt.legend(loc='upper right',bbox_to_anchor=(1.8,1),fontsize=12)
    plt.savefig("4-5_Bolzmann.png",format = 'png', dpi=300)
    plt.show()
    ########################################################################
    ####Writing data (overwrite if exsited)#################################
    with open(pathOUT2, mode='w') as f:
        f.write(" slope, Te, errTe, intercept, errInter, Us, F, Cs,Cs2 \n")
    output2=np.c_[m, Te, errTe, qs, errqs, Us, F, Cs, Cs2]
    print(Us, Us2, F, Cs, Cs2)
    with open(pathOUT2, mode='ab') as f:
        np.savetxt(f,output2, fmt='%.4e',delimiter=', ')
    ########################################################################
    ####Writing summary data (overwrite)####################################
    if i==1:
        with open("../"+pathOUT3, mode='w') as f:
            f.write("filename, Te(eV), errTe(eV), "+Mat1st+"-I, "+Mat2nd+"-I in "+Mat+"\n")

        print(Us, Us2, F, Cs, Cs2)
    
    ####Writing summary data################################################
    output3=np.c_[Te, errTe, Cs, Cs2]
    with open("../"+pathOUT3, mode='a') as f:
        f.write(datapath+', ')
    with open("../"+pathOUT3, mode='ab') as f:
        np.savetxt(f,output3, fmt='%.4e',delimiter=', ')
    ########################################################################
    os.chdir(loop_dir)
############################################################################


os.chdir(init_dir)
    
############################################################################
# Out:
# initial directory
# C:\Users\Ibano\Anaconda3\jupyter\LIBS
# LibWavelength [ 370.7922  426.9382  449.4497  484.381   488.6899  505.3276  522.4657
#   551.4676]
# loop number=1, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_001.cdat
# Spectral-fit #0 is DONE
# ['m1=370.84 ', 'sd1=0.04 ', 'a1=7.56e+18 ', 'BG=1.523e+18x-5.530e+20 ', 'eqint=7.56e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.97 ', 'sd1=0.04 ', 'a1=2.70e+19 ', 'BG=4.169e+18x-1.757e+21 ', 'eqint=2.70e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.47 ', 'sd1=0.05 ', 'a1=2.60e+18 ', 'BG=7.197e+18x-3.220e+21 ', 'eqint=2.60e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.43 ', 'sd1=0.05 ', 'a1=2.91e+19 ', 'BG=1.333e+18x-6.336e+20 ', 'eqint=2.91e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.72 ', 'sd1=0.05 ', 'a1=1.63e+19 ', 'BG=1.273e+19x-6.208e+21 ', 'eqint=1.63e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.38 ', 'sd1=0.06 ', 'a1=3.18e+19 ', 'BG=1.275e+19x-6.427e+21 ', 'eqint=3.18e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.52 ', 'sd1=0.05 ', 'a1=1.94e+19 ', 'BG=-1.195e+18x+6.324e+20 ', 'eqint=1.94e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.53 ', 'sd1=0.05 ', 'a1=1.29e+19 ', 'BG=1.390e+18x-7.588e+20 ', 'eqint=1.29e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_001
# 23.5016577379 12.7407530631 8.32984935841e+15 0.987936648057 0.0120633519427
# 23.5016577379 12.7407530631 8.32984935841e+15 0.987936648057 0.0120633519427
# loop number=2, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_002.cdat
# Spectral-fit #0 is DONE
# ['m1=370.84 ', 'sd1=0.04 ', 'a1=7.96e+18 ', 'BG=7.708e+17x-2.745e+20 ', 'eqint=7.96e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.97 ', 'sd1=0.04 ', 'a1=2.49e+19 ', 'BG=4.247e+18x-1.792e+21 ', 'eqint=2.49e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.48 ', 'sd1=0.05 ', 'a1=2.95e+18 ', 'BG=4.757e+18x-2.124e+21 ', 'eqint=2.95e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.43 ', 'sd1=0.05 ', 'a1=2.87e+19 ', 'BG=-2.356e+16x+2.309e+19 ', 'eqint=2.87e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.72 ', 'sd1=0.05 ', 'a1=1.70e+19 ', 'BG=9.582e+18x-4.667e+21 ', 'eqint=1.70e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.37 ', 'sd1=0.06 ', 'a1=3.33e+19 ', 'BG=1.226e+19x-6.181e+21 ', 'eqint=3.33e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.52 ', 'sd1=0.05 ', 'a1=1.97e+19 ', 'BG=-1.261e+18x+6.671e+20 ', 'eqint=1.97e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.53 ', 'sd1=0.05 ', 'a1=1.23e+19 ', 'BG=8.421e+17x-4.569e+20 ', 'eqint=1.23e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_002
# 25.1508571487 13.6486899728 7.56985239336e+15 0.984964098129 0.0150359018714
# loop number=3, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_003.cdat
# Spectral-fit #0 is DONE
# ['m1=370.84 ', 'sd1=0.04 ', 'a1=8.17e+18 ', 'BG=3.619e+18x-1.332e+21 ', 'eqint=8.17e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.97 ', 'sd1=0.04 ', 'a1=2.76e+19 ', 'BG=4.917e+18x-2.078e+21 ', 'eqint=2.76e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.46 ', 'sd1=0.05 ', 'a1=2.99e+18 ', 'BG=5.402e+18x-2.413e+21 ', 'eqint=2.99e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.43 ', 'sd1=0.05 ', 'a1=3.05e+19 ', 'BG=1.753e+17x-7.343e+19 ', 'eqint=3.05e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.72 ', 'sd1=0.05 ', 'a1=1.58e+19 ', 'BG=1.002e+19x-4.883e+21 ', 'eqint=1.58e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.37 ', 'sd1=0.06 ', 'a1=3.24e+19 ', 'BG=1.432e+19x-7.219e+21 ', 'eqint=3.24e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.51 ', 'sd1=0.05 ', 'a1=1.96e+19 ', 'BG=-6.090e+17x+3.265e+20 ', 'eqint=1.96e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.53 ', 'sd1=0.05 ', 'a1=1.21e+19 ', 'BG=-1.492e+18x+8.309e+20 ', 'eqint=1.21e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_003
# 25.4080569399 13.7902866664 7.48504556899e+15 0.989883531449 0.0101164685511
# loop number=4, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_004.cdat
# Spectral-fit #0 is DONE
# ['m1=370.83 ', 'sd1=0.04 ', 'a1=7.74e+18 ', 'BG=-2.450e+18x+9.200e+20 ', 'eqint=7.74e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.97 ', 'sd1=0.04 ', 'a1=2.62e+19 ', 'BG=5.989e+18x-2.535e+21 ', 'eqint=2.62e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.48 ', 'sd1=0.06 ', 'a1=3.52e+18 ', 'BG=-6.446e+17x+3.041e+20 ', 'eqint=3.52e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.43 ', 'sd1=0.05 ', 'a1=2.99e+19 ', 'BG=1.758e+17x-7.350e+19 ', 'eqint=2.99e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.72 ', 'sd1=0.05 ', 'a1=1.65e+19 ', 'BG=8.851e+18x-4.310e+21 ', 'eqint=1.65e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.37 ', 'sd1=0.06 ', 'a1=3.25e+19 ', 'BG=1.355e+19x-6.829e+21 ', 'eqint=3.25e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.52 ', 'sd1=0.05 ', 'a1=1.91e+19 ', 'BG=-9.509e+17x+5.049e+20 ', 'eqint=1.91e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.52 ', 'sd1=0.05 ', 'a1=1.28e+19 ', 'BG=5.350e+17x-2.872e+20 ', 'eqint=1.28e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_004
# 27.2107147434 14.7827073188 6.76973788608e+15 0.989661756827 0.0103382431729
# loop number=5, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_005.cdat
# Spectral-fit #0 is DONE
# ['m1=370.83 ', 'sd1=0.04 ', 'a1=8.26e+18 ', 'BG=9.203e+17x-3.274e+20 ', 'eqint=8.26e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.96 ', 'sd1=0.04 ', 'a1=2.84e+19 ', 'BG=6.059e+18x-2.565e+21 ', 'eqint=2.84e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.47 ', 'sd1=0.05 ', 'a1=3.25e+18 ', 'BG=5.464e+18x-2.441e+21 ', 'eqint=3.25e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.42 ', 'sd1=0.05 ', 'a1=3.13e+19 ', 'BG=1.498e+17x-6.087e+19 ', 'eqint=3.13e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.71 ', 'sd1=0.05 ', 'a1=1.67e+19 ', 'BG=9.571e+18x-4.662e+21 ', 'eqint=1.67e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.36 ', 'sd1=0.06 ', 'a1=3.45e+19 ', 'BG=1.241e+19x-6.251e+21 ', 'eqint=3.45e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.51 ', 'sd1=0.05 ', 'a1=2.08e+19 ', 'BG=-1.815e+18x+9.570e+20 ', 'eqint=2.08e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.52 ', 'sd1=0.05 ', 'a1=1.27e+19 ', 'BG=-7.898e+17x+4.433e+20 ', 'eqint=1.27e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_005
# 25.7368311743 13.9712873752 7.63570399767e+15 0.994719999124 0.0052800008755
# loop number=6, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_006.cdat
# Spectral-fit #0 is DONE
# ['m1=370.83 ', 'sd1=0.04 ', 'a1=8.49e+18 ', 'BG=-2.136e+18x+8.053e+20 ', 'eqint=8.49e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.96 ', 'sd1=0.04 ', 'a1=2.78e+19 ', 'BG=3.056e+18x-1.283e+21 ', 'eqint=2.78e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.46 ', 'sd1=0.05 ', 'a1=3.49e+18 ', 'BG=2.425e+18x-1.075e+21 ', 'eqint=3.49e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.42 ', 'sd1=0.05 ', 'a1=3.24e+19 ', 'BG=1.103e+18x-5.224e+20 ', 'eqint=3.24e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.71 ', 'sd1=0.05 ', 'a1=1.71e+19 ', 'BG=7.795e+18x-3.794e+21 ', 'eqint=1.71e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.36 ', 'sd1=0.06 ', 'a1=3.49e+19 ', 'BG=1.334e+19x-6.722e+21 ', 'eqint=3.49e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.51 ', 'sd1=0.05 ', 'a1=1.97e+19 ', 'BG=-1.643e+18x+8.667e+20 ', 'eqint=1.97e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.51 ', 'sd1=0.05 ', 'a1=1.35e+19 ', 'BG=-9.544e+17x+5.335e+20 ', 'eqint=1.35e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_006
# 26.4111378553 14.3425147235 7.47827847325e+15 0.991126832321 0.00887316767928
# loop number=7, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_007.cdat
# Spectral-fit #0 is DONE
# ['m1=370.84 ', 'sd1=0.04 ', 'a1=9.37e+18 ', 'BG=2.683e+18x-9.835e+20 ', 'eqint=9.37e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.96 ', 'sd1=0.04 ', 'a1=2.74e+19 ', 'BG=-3.119e+18x+1.353e+21 ', 'eqint=2.74e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.46 ', 'sd1=0.05 ', 'a1=3.33e+18 ', 'BG=2.914e+18x-1.295e+21 ', 'eqint=3.33e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.42 ', 'sd1=0.05 ', 'a1=3.17e+19 ', 'BG=1.746e+18x-8.334e+20 ', 'eqint=3.17e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.71 ', 'sd1=0.05 ', 'a1=1.75e+19 ', 'BG=9.438e+18x-4.597e+21 ', 'eqint=1.75e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.36 ', 'sd1=0.06 ', 'a1=3.48e+19 ', 'BG=1.428e+19x-7.198e+21 ', 'eqint=3.48e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.50 ', 'sd1=0.05 ', 'a1=2.08e+19 ', 'BG=4.203e+17x-2.112e+20 ', 'eqint=2.08e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.51 ', 'sd1=0.05 ', 'a1=1.39e+19 ', 'BG=3.855e+17x-2.049e+20 ', 'eqint=1.39e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_007
# 25.8552425957 14.0364766418 7.92756293169e+15 0.984284192482 0.0157158075183
# loop number=8, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_008.cdat
# Spectral-fit #0 is DONE
# ['m1=370.83 ', 'sd1=0.04 ', 'a1=8.23e+18 ', 'BG=3.627e+18x-1.330e+21 ', 'eqint=8.23e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.96 ', 'sd1=0.04 ', 'a1=2.88e+19 ', 'BG=6.239e+18x-2.641e+21 ', 'eqint=2.88e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.46 ', 'sd1=0.05 ', 'a1=3.12e+18 ', 'BG=1.302e+18x-5.699e+20 ', 'eqint=3.12e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.42 ', 'sd1=0.05 ', 'a1=3.21e+19 ', 'BG=-1.135e+18x+5.621e+20 ', 'eqint=3.21e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.71 ', 'sd1=0.05 ', 'a1=1.82e+19 ', 'BG=8.781e+18x-4.275e+21 ', 'eqint=1.82e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.36 ', 'sd1=0.06 ', 'a1=3.42e+19 ', 'BG=1.713e+19x-8.637e+21 ', 'eqint=3.42e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.51 ', 'sd1=0.05 ', 'a1=2.17e+19 ', 'BG=-2.699e+18x+1.418e+21 ', 'eqint=2.17e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.51 ', 'sd1=0.05 ', 'a1=1.36e+19 ', 'BG=-1.733e+18x+9.641e+20 ', 'eqint=1.36e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_008
# 24.7694152599 13.4386940394 8.40372110112e+15 0.98741144379 0.0125885562104
# loop number=9, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_009.cdat
# Spectral-fit #0 is DONE
# ['m1=370.83 ', 'sd1=0.04 ', 'a1=7.90e+18 ', 'BG=1.462e+18x-5.294e+20 ', 'eqint=7.90e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.96 ', 'sd1=0.04 ', 'a1=2.54e+19 ', 'BG=-1.265e+18x+5.616e+20 ', 'eqint=2.54e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.46 ', 'sd1=0.05 ', 'a1=3.23e+18 ', 'BG=5.694e+18x-2.545e+21 ', 'eqint=3.23e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.41 ', 'sd1=0.05 ', 'a1=2.83e+19 ', 'BG=1.804e+18x-8.621e+20 ', 'eqint=2.83e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.71 ', 'sd1=0.04 ', 'a1=1.18e+19 ', 'BG=4.574e+19x-2.232e+22 ', 'eqint=1.18e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.36 ', 'sd1=0.06 ', 'a1=3.16e+19 ', 'BG=1.220e+19x-6.150e+21 ', 'eqint=3.16e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.50 ', 'sd1=0.05 ', 'a1=1.89e+19 ', 'BG=-1.957e+18x+1.030e+21 ', 'eqint=1.89e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.51 ', 'sd1=0.05 ', 'a1=1.19e+19 ', 'BG=-1.474e+17x+8.836e+19 ', 'eqint=1.19e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_009
# 26.8937902931 14.6082302943 7.60595453671e+15 0.83259192492 0.16740807508
# loop number=10, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_010.cdat
# Spectral-fit #0 is DONE
# ['m1=370.83 ', 'sd1=0.04 ', 'a1=7.75e+18 ', 'BG=-7.610e+17x+2.941e+20 ', 'eqint=7.75e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.96 ', 'sd1=0.04 ', 'a1=2.52e+19 ', 'BG=7.590e+17x-3.047e+20 ', 'eqint=2.52e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.46 ', 'sd1=0.06 ', 'a1=2.87e+18 ', 'BG=4.434e+18x-1.980e+21 ', 'eqint=2.87e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.41 ', 'sd1=0.05 ', 'a1=2.70e+19 ', 'BG=3.674e+18x-1.768e+21 ', 'eqint=2.70e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.70 ', 'sd1=0.04 ', 'a1=1.11e+19 ', 'BG=4.634e+19x-2.261e+22 ', 'eqint=1.11e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.36 ', 'sd1=0.06 ', 'a1=3.04e+19 ', 'BG=1.112e+19x-5.608e+21 ', 'eqint=3.04e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.50 ', 'sd1=0.05 ', 'a1=1.79e+19 ', 'BG=-4.128e+17x+2.229e+20 ', 'eqint=1.79e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.51 ', 'sd1=0.05 ', 'a1=1.19e+19 ', 'BG=-6.752e+17x+3.786e+20 ', 'eqint=1.19e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_0010
# 25.7902251957 14.0006824881 7.64467573309e+15 0.851199309549 0.148800690451
# loop number=11, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_011.cdat
# Spectral-fit #0 is DONE
# ['m1=370.82 ', 'sd1=0.04 ', 'a1=6.23e+18 ', 'BG=4.484e+17x-1.549e+20 ', 'eqint=6.23e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.95 ', 'sd1=0.04 ', 'a1=2.01e+19 ', 'BG=-3.487e+17x+1.672e+20 ', 'eqint=2.01e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.45 ', 'sd1=0.05 ', 'a1=1.85e+18 ', 'BG=3.409e+18x-1.520e+21 ', 'eqint=1.85e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.41 ', 'sd1=0.05 ', 'a1=2.25e+19 ', 'BG=8.977e+17x-4.251e+20 ', 'eqint=2.25e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.70 ', 'sd1=0.04 ', 'a1=1.08e+19 ', 'BG=3.984e+19x-1.944e+22 ', 'eqint=1.08e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.36 ', 'sd1=0.06 ', 'a1=2.46e+19 ', 'BG=1.154e+19x-5.817e+21 ', 'eqint=2.46e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.50 ', 'sd1=0.05 ', 'a1=1.47e+19 ', 'BG=-1.451e+18x+7.646e+20 ', 'eqint=1.47e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.51 ', 'sd1=0.05 ', 'a1=9.66e+18 ', 'BG=-1.483e+17x+8.750e+19 ', 'eqint=9.66e+18 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_0011
# 22.9327540906 12.4275534488 7.49032711382e+15 0.857569109202 0.142430890798
# loop number=12, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_012.cdat
# Spectral-fit #0 is DONE
# ['m1=370.82 ', 'sd1=0.04 ', 'a1=6.10e+18 ', 'BG=1.355e+18x-4.910e+20 ', 'eqint=6.10e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.96 ', 'sd1=0.04 ', 'a1=2.15e+19 ', 'BG=-1.485e+18x+6.518e+20 ', 'eqint=2.15e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.46 ', 'sd1=0.05 ', 'a1=2.43e+18 ', 'BG=-2.548e+16x+2.332e+19 ', 'eqint=2.43e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.41 ', 'sd1=0.05 ', 'a1=2.26e+19 ', 'BG=1.504e+18x-7.184e+20 ', 'eqint=2.26e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.70 ', 'sd1=0.04 ', 'a1=9.95e+18 ', 'BG=4.129e+19x-2.015e+22 ', 'eqint=9.95e+18 ']
# Spectral-fit #5 is DONE
# ['m1=505.36 ', 'sd1=0.06 ', 'a1=2.58e+19 ', 'BG=1.045e+19x-5.266e+21 ', 'eqint=2.58e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.50 ', 'sd1=0.05 ', 'a1=1.58e+19 ', 'BG=-1.403e+18x+7.400e+20 ', 'eqint=1.58e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.51 ', 'sd1=0.05 ', 'a1=8.66e+18 ', 'BG=1.240e+18x-6.778e+20 ', 'eqint=8.66e+18 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_0012
# 26.2108410982 14.2322449663 6.26585412514e+15 0.842601751427 0.157398248573
# loop number=13, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_013.cdat
# Spectral-fit #0 is DONE
# ['m1=370.83 ', 'sd1=0.04 ', 'a1=6.04e+18 ', 'BG=1.585e+18x-5.758e+20 ', 'eqint=6.04e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.96 ', 'sd1=0.04 ', 'a1=2.35e+19 ', 'BG=-1.644e+18x+7.250e+20 ', 'eqint=2.35e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.46 ', 'sd1=0.06 ', 'a1=2.73e+18 ', 'BG=2.455e+18x-1.089e+21 ', 'eqint=2.73e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.41 ', 'sd1=0.05 ', 'a1=2.53e+19 ', 'BG=3.135e+17x-1.408e+20 ', 'eqint=2.53e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.70 ', 'sd1=0.05 ', 'a1=1.44e+19 ', 'BG=1.470e+19x-7.165e+21 ', 'eqint=1.44e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.36 ', 'sd1=0.06 ', 'a1=2.97e+19 ', 'BG=1.061e+19x-5.346e+21 ', 'eqint=2.97e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.50 ', 'sd1=0.05 ', 'a1=1.67e+19 ', 'BG=-4.578e+17x+2.467e+20 ', 'eqint=1.67e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.51 ', 'sd1=0.05 ', 'a1=1.01e+19 ', 'BG=1.954e+16x-3.586e+18 ', 'eqint=1.01e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_0013
# 25.706103944 13.9543710543 6.50892662467e+15 0.953389632397 0.0466103676029
# loop number=14, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_014.cdat
# Spectral-fit #0 is DONE
# ['m1=370.82 ', 'sd1=0.04 ', 'a1=7.68e+18 ', 'BG=4.723e+17x-1.634e+20 ', 'eqint=7.68e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.96 ', 'sd1=0.04 ', 'a1=2.17e+19 ', 'BG=-2.978e+17x+1.473e+20 ', 'eqint=2.17e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.46 ', 'sd1=0.05 ', 'a1=2.63e+18 ', 'BG=1.231e+18x-5.399e+20 ', 'eqint=2.63e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.41 ', 'sd1=0.05 ', 'a1=2.59e+19 ', 'BG=1.337e+18x-6.352e+20 ', 'eqint=2.59e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.70 ', 'sd1=0.05 ', 'a1=1.34e+19 ', 'BG=1.664e+19x-8.114e+21 ', 'eqint=1.34e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.36 ', 'sd1=0.06 ', 'a1=2.91e+19 ', 'BG=1.286e+19x-6.482e+21 ', 'eqint=2.91e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.50 ', 'sd1=0.05 ', 'a1=1.75e+19 ', 'BG=-6.448e+17x+3.446e+20 ', 'eqint=1.75e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.51 ', 'sd1=0.05 ', 'a1=1.03e+19 ', 'BG=-5.440e+17x+3.074e+20 ', 'eqint=1.03e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_0014
# 25.7616201942 13.9849345218 6.58057509723e+15 0.952929655593 0.0470703444067
# loop number=15, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_015.cdat
# Spectral-fit #0 is DONE
# ['m1=370.83 ', 'sd1=0.04 ', 'a1=7.60e+18 ', 'BG=6.708e+18x-2.476e+21 ', 'eqint=7.60e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.96 ', 'sd1=0.04 ', 'a1=2.17e+19 ', 'BG=1.392e+18x-5.752e+20 ', 'eqint=2.17e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.46 ', 'sd1=0.06 ', 'a1=2.71e+18 ', 'BG=2.798e+18x-1.244e+21 ', 'eqint=2.71e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.41 ', 'sd1=0.05 ', 'a1=2.52e+19 ', 'BG=1.310e+18x-6.232e+20 ', 'eqint=2.52e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.70 ', 'sd1=0.04 ', 'a1=1.33e+19 ', 'BG=1.663e+19x-8.109e+21 ', 'eqint=1.33e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.36 ', 'sd1=0.06 ', 'a1=2.89e+19 ', 'BG=1.065e+19x-5.367e+21 ', 'eqint=2.89e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.50 ', 'sd1=0.05 ', 'a1=1.77e+19 ', 'BG=-1.064e+18x+5.627e+20 ', 'eqint=1.77e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.51 ', 'sd1=0.05 ', 'a1=1.12e+19 ', 'BG=7.386e+17x-4.002e+20 ', 'eqint=1.12e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_0015
# 25.7863656359 13.9985576772 6.61200962954e+15 0.956013429097 0.0439865709028
# loop number=16, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_016.cdat
# Spectral-fit #0 is DONE
# ['m1=370.83 ', 'sd1=0.05 ', 'a1=6.10e+18 ', 'BG=4.504e+18x-1.660e+21 ', 'eqint=6.10e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.96 ', 'sd1=0.04 ', 'a1=2.27e+19 ', 'BG=4.377e+18x-1.847e+21 ', 'eqint=2.27e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.46 ', 'sd1=0.05 ', 'a1=2.51e+18 ', 'BG=5.066e+18x-2.263e+21 ', 'eqint=2.51e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.41 ', 'sd1=0.05 ', 'a1=2.69e+19 ', 'BG=1.993e+17x-8.567e+19 ', 'eqint=2.69e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.70 ', 'sd1=0.05 ', 'a1=1.41e+19 ', 'BG=1.639e+19x-7.991e+21 ', 'eqint=1.41e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.36 ', 'sd1=0.06 ', 'a1=2.97e+19 ', 'BG=1.077e+19x-5.428e+21 ', 'eqint=2.97e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.50 ', 'sd1=0.05 ', 'a1=1.73e+19 ', 'BG=-1.527e+18x+8.052e+20 ', 'eqint=1.73e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.50 ', 'sd1=0.06 ', 'a1=9.91e+18 ', 'BG=1.677e+18x-9.175e+20 ', 'eqint=9.91e+18 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_0016
# 24.5960328321 13.3432414794 6.9852022772e+15 0.951383752753 0.0486162472465
# loop number=17, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_017.cdat
# Spectral-fit #0 is DONE
# ['m1=370.83 ', 'sd1=0.05 ', 'a1=9.68e+18 ', 'BG=2.344e+18x-8.560e+20 ', 'eqint=9.68e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.96 ', 'sd1=0.04 ', 'a1=2.69e+19 ', 'BG=3.210e+18x-1.347e+21 ', 'eqint=2.69e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.45 ', 'sd1=0.05 ', 'a1=3.59e+18 ', 'BG=6.665e+18x-2.980e+21 ', 'eqint=3.59e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.41 ', 'sd1=0.05 ', 'a1=2.96e+19 ', 'BG=-2.317e+17x+1.252e+20 ', 'eqint=2.96e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.71 ', 'sd1=0.05 ', 'a1=1.74e+19 ', 'BG=8.333e+18x-4.058e+21 ', 'eqint=1.74e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.36 ', 'sd1=0.06 ', 'a1=3.41e+19 ', 'BG=1.517e+19x-7.647e+21 ', 'eqint=3.41e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.50 ', 'sd1=0.05 ', 'a1=1.95e+19 ', 'BG=7.457e+17x-3.814e+20 ', 'eqint=1.95e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.51 ', 'sd1=0.05 ', 'a1=1.24e+19 ', 'BG=-1.454e+18x+8.091e+20 ', 'eqint=1.24e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_0017
# 27.9748396312 15.2033824565 6.76571958909e+15 0.98678921018 0.0132107898201
# loop number=18, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_018.cdat
# Spectral-fit #0 is DONE
# ['m1=370.82 ', 'sd1=0.04 ', 'a1=8.19e+18 ', 'BG=1.408e+18x-5.094e+20 ', 'eqint=8.19e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.96 ', 'sd1=0.04 ', 'a1=2.75e+19 ', 'BG=5.270e+17x-2.034e+20 ', 'eqint=2.75e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.46 ', 'sd1=0.05 ', 'a1=3.58e+18 ', 'BG=6.480e+18x-2.898e+21 ', 'eqint=3.58e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.41 ', 'sd1=0.05 ', 'a1=3.07e+19 ', 'BG=2.698e+18x-1.295e+21 ', 'eqint=3.07e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.71 ', 'sd1=0.05 ', 'a1=1.59e+19 ', 'BG=8.434e+18x-4.107e+21 ', 'eqint=1.59e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.35 ', 'sd1=0.06 ', 'a1=3.31e+19 ', 'BG=1.239e+19x-6.241e+21 ', 'eqint=3.31e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.50 ', 'sd1=0.05 ', 'a1=2.01e+19 ', 'BG=-1.970e+18x+1.038e+21 ', 'eqint=2.01e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.51 ', 'sd1=0.05 ', 'a1=1.15e+19 ', 'BG=5.015e+17x-2.692e+20 ', 'eqint=1.15e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_0018
# 27.7864497056 15.09966779 6.58012914589e+15 0.991040020154 0.00895997984586
# loop number=19, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_019.cdat
# Spectral-fit #0 is DONE
# ['m1=370.82 ', 'sd1=0.04 ', 'a1=4.97e+18 ', 'BG=3.157e+18x-1.160e+21 ', 'eqint=4.97e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.95 ', 'sd1=0.04 ', 'a1=2.22e+19 ', 'BG=-1.833e+17x+9.730e+19 ', 'eqint=2.22e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.46 ', 'sd1=0.05 ', 'a1=1.94e+18 ', 'BG=5.275e+18x-2.358e+21 ', 'eqint=1.94e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.41 ', 'sd1=0.05 ', 'a1=2.35e+19 ', 'BG=3.007e+16x-3.508e+18 ', 'eqint=2.35e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.70 ', 'sd1=0.05 ', 'a1=1.43e+19 ', 'BG=7.952e+18x-3.873e+21 ', 'eqint=1.43e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.36 ', 'sd1=0.06 ', 'a1=2.50e+19 ', 'BG=1.310e+19x-6.603e+21 ', 'eqint=2.50e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.50 ', 'sd1=0.05 ', 'a1=1.50e+19 ', 'BG=-9.799e+17x+5.192e+20 ', 'eqint=1.50e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.51 ', 'sd1=0.05 ', 'a1=9.88e+18 ', 'BG=-2.192e+17x+1.274e+20 ', 'eqint=9.88e+18 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_0019
# 22.5914081477 12.2396316133 6.89038776338e+15 0.993152313505 0.00684768649452
# loop number=20, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_020.cdat
# Spectral-fit #0 is DONE
# ['m1=370.83 ', 'sd1=0.04 ', 'a1=6.00e+18 ', 'BG=8.087e+17x-2.869e+20 ', 'eqint=6.00e+18 ']
# Spectral-fit #1 is DONE
# ['m1=426.95 ', 'sd1=0.04 ', 'a1=2.20e+19 ', 'BG=1.421e+17x-4.155e+19 ', 'eqint=2.20e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.45 ', 'sd1=0.05 ', 'a1=2.53e+18 ', 'BG=2.791e+18x-1.241e+21 ', 'eqint=2.53e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.41 ', 'sd1=0.05 ', 'a1=2.46e+19 ', 'BG=-6.486e+15x+1.463e+19 ', 'eqint=2.46e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.70 ', 'sd1=0.05 ', 'a1=1.40e+19 ', 'BG=7.545e+18x-3.673e+21 ', 'eqint=1.40e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.35 ', 'sd1=0.06 ', 'a1=2.62e+19 ', 'BG=1.293e+19x-6.520e+21 ', 'eqint=2.62e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.49 ', 'sd1=0.05 ', 'a1=1.57e+19 ', 'BG=-3.389e+17x+1.846e+20 ', 'eqint=1.57e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.50 ', 'sd1=0.05 ', 'a1=1.01e+19 ', 'BG=1.207e+17x-5.955e+19 ', 'eqint=1.01e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_0020
# 25.5764994173 13.883019626 5.99994548294e+15 0.993417076957 0.00658292304335
# loop number=21, dir?
# C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000
# cdat/A_021.cdat
# C:\Users\Ibano\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:436: RuntimeWarning: Number of calls to function has reached maxfev = 1200.
#   warnings.warn(errors[info][0], RuntimeWarning)
# Spectral-fit #0 is DONE
# ['m1=371.28 ', 'sd1=0.17 ', 'a1=-9.19e+18 ', 'BG=1.730e+19x-6.393e+21 ', 'eqint=-9.14e+18 ']
# C:\Users\Ibano\Anaconda3\lib\site-packages\ipykernel_launcher.py:147: RuntimeWarning: invalid value encountered in log
# Spectral-fit #1 is DONE
# ['m1=426.95 ', 'sd1=0.04 ', 'a1=2.33e+19 ', 'BG=9.349e+17x-3.792e+20 ', 'eqint=2.33e+19 ']
# Spectral-fit #2 is DONE
# ['m1=449.45 ', 'sd1=0.06 ', 'a1=2.63e+18 ', 'BG=4.640e+18x-2.072e+21 ', 'eqint=2.63e+18 ']
# Spectral-fit #3 is DONE
# ['m1=484.41 ', 'sd1=0.05 ', 'a1=2.64e+19 ', 'BG=2.167e+18x-1.038e+21 ', 'eqint=2.64e+19 ']
# Spectral-fit #4 is DONE
# ['m1=488.70 ', 'sd1=0.04 ', 'a1=1.41e+19 ', 'BG=7.811e+18x-3.803e+21 ', 'eqint=1.41e+19 ']
# Spectral-fit #5 is DONE
# ['m1=505.35 ', 'sd1=0.05 ', 'a1=2.80e+19 ', 'BG=1.181e+19x-5.951e+21 ', 'eqint=2.80e+19 ']
# Spectral-fit #6 is DONE
# ['m1=522.49 ', 'sd1=0.05 ', 'a1=1.58e+19 ', 'BG=-7.938e+17x+4.224e+20 ', 'eqint=1.58e+19 ']
# Spectral-fit #7 is DONE
# ['m1=551.50 ', 'sd1=0.05 ', 'a1=1.00e+19 ', 'BG=5.165e+17x-2.773e+20 ', 'eqint=1.00e+19 ']
# RESULT
# current dir C:\Users\Ibano\Anaconda3\jupyter\LIBS\20180918\ME5000\python\MechelleSpect_0021
# 28.7343978186 15.6215434799 5.95281237075e+15 0.980298663921 0.0197013360792
